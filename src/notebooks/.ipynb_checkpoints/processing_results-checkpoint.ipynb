# %%
import os
import glob
import seaborn as sns
import pandas as pd

# %%
all_paths = "/Users/amuhebwa/Documents/Stanford/Research_Code/CarbonMeasure_Responsibility/src/results/carbon_tracker"
all_files = glob.glob(f'{all_paths}/*.csv')
all_dfs = []
for fpath in all_files:
    temp_df = pd.read_csv(fpath)
    full_model_name = fpath.split('/').pop().split('.')[0][:-20].strip()
    temp_df['full_model_name'] = full_model_name
    temp_df = temp_df[['full_model_name', 'duration', 'emissions', 'emissions_rate', 'energy_consumed', 'gpu_energy']]
    all_dfs.append(temp_df)
combined_df = pd.concat(all_dfs)
combined_df = combined_df.sort_values(by=['energy_consumed'], ascending=False).reset_index(drop=True)
combined_df = combined_df.drop_duplicates(subset=['full_model_name']).reset_index(drop=True)

# %%
metrics_path = "/Users/amuhebwa/Documents/Stanford/Research_Code/CarbonMeasure_Responsibility/src/results/metrics"
metrics_files = glob.glob(f"{metrics_path}/*.csv")
all_dfs = []
for fpath in metrics_files:
    temp_df = pd.read_csv(fpath)
    full_model_name = fpath.split('/').pop().split('.')[0][:-8].strip()
    temp_df['full_model_name'] = full_model_name
    temp_df['model_size'] = 'Small' if "small" in model_name.split('_') else 'Tiny'
    temp_df['model_id'] = temp_df.iloc[0, :]['model_name'].split('_')[0]
    all_dfs.append(temp_df)
combined_metrics = pd.concat(all_dfs).reset_index(drop=True)

# %%
final_df = pd.merge(combined_df, combined_metrics, on=['full_model_name'])
final_df =  final_df.sort_values(by=['energy_consumed'], ascending=False).reset_index(drop=True)
final_df.to_csv('/Users/amuhebwa/Documents/Stanford/Research_Code/CarbonMeasure_Responsibility/src/results/merged_metrics.csv', index=False)

# %%
final_df
# Out:
#                                      full_model_name      duration  emissions  \
# 0                         EuroSAT_convnext_small_224  23511.337307   0.026128
# 1                PublicHarvestNet_convnext_small_224  15985.550091   0.017468
# 2                          EuroSAT_convnext_tiny_224  14560.752334   0.016284
# 3                 PublicHarvestNet_convnext_tiny_224   9783.975709   0.011218
# 4            EuroSAT_swinv2_small_patch4_window8_256   7248.966017   0.008626
# 5            EuroSAT_swinv2_tiny_patch4_window16_256   5489.837448   0.006482
# 6   PublicHarvestNet_swinv2_small_patch4_window8_256   5110.552306   0.005896
# 7   PublicHarvestNet_swinv2_tiny_patch4_window16_256   3865.618568   0.004486
# 8                      EuroSAT_vit_small_patch16_224   2316.935358   0.002646
# 9                     Kenya_Roads_convnext_small_224   2167.805367   0.002371
# 10                    EuroSAT_deit_small_patch16_224   2002.823451   0.002161
# 11            PublicHarvestNet_vit_small_patch16_224   1775.171657   0.001870
# 12           PublicHarvestNet_deit_small_patch16_224   1613.367320   0.001632
# 13                     Kenya_Roads_convnext_tiny_224   1302.761502   0.001517
# 14                      EuroSAT_vit_tiny_patch16_224   1762.710993   0.001491
# 15                     EuroSAT_deit_tiny_patch16_224   1559.222229   0.001297
# 16             PublicHarvestNet_vit_tiny_patch16_224   1378.278401   0.001137
# 17            PublicHarvestNet_deit_tiny_patch16_224   1254.514769   0.001033
# 18       Kenya_Roads_swinv2_small_patch4_window8_256    667.847464   0.000805
# 19       Kenya_Roads_swinv2_tiny_patch4_window16_256    501.614963   0.000589
# 20                 Kenya_Roads_vit_small_patch16_224    216.244709   0.000244
# 21                Kenya_Roads_deit_small_patch16_224    190.456949   0.000216
# 22                  Kenya_Roads_vit_tiny_patch16_224    160.637655   0.000151
# 23                 Kenya_Roads_deit_tiny_patch16_224    141.632810   0.000134
#
#     emissions_rate  energy_consumed  gpu_energy   experiment_name  \
# 0     1.111275e-06         0.127284    0.084074           EuroSAT
# 1     1.092711e-06         0.085096    0.055202  PublicHarvestNet
# 2     1.118324e-06         0.079328    0.048516           EuroSAT
# 3     1.146561e-06         0.054650    0.033217  PublicHarvestNet
# 4     1.189984e-06         0.042024    0.017479           EuroSAT
# 5     1.180695e-06         0.031577    0.013096           EuroSAT
# 6     1.153708e-06         0.028724    0.011469  PublicHarvestNet
# 7     1.160512e-06         0.021855    0.008857  PublicHarvestNet
# 8     1.141909e-06         0.012889    0.005072           EuroSAT
# 9     1.093646e-06         0.011550    0.007579       Kenya_Roads
# 10    1.079175e-06         0.010530    0.003642           EuroSAT
# 11    1.053412e-06         0.009110    0.003050  PublicHarvestNet
# 12    1.011598e-06         0.007951    0.002407  PublicHarvestNet
# 13    1.164126e-06         0.007388    0.004616       Kenya_Roads
# 14    8.459632e-07         0.007265    0.001111           EuroSAT
# 15    8.317441e-07         0.006318    0.000918           EuroSAT
# 16    8.252442e-07         0.005541    0.000733  PublicHarvestNet
# 17    8.232774e-07         0.005032    0.000619  PublicHarvestNet
# 18    1.205078e-06         0.003921    0.001635       Kenya_Roads
# 19    1.174209e-06         0.002869    0.001212       Kenya_Roads
# 20    1.129712e-06         0.001190    0.000476       Kenya_Roads
# 21    1.135004e-06         0.001053    0.000412       Kenya_Roads
# 22    9.419340e-07         0.000737    0.000191       Kenya_Roads
# 23    9.453729e-07         0.000652    0.000157       Kenya_Roads
#
#                          model_name  accuracy     auroc       mcc        f1  \
# 0                convnext_small_224  0.951081       NaN  0.945562  0.951111
# 1                convnext_small_224  0.783960  0.495002  0.563191  0.750626
# 2                 convnext_tiny_224  0.959509       NaN  0.954929  0.959517
# 3                 convnext_tiny_224  0.775289  0.453775  0.546102  0.749799
# 4   swinv2_small_patch4_window8_256  0.985709       NaN  0.984097  0.985708
# 5   swinv2_tiny_patch4_window16_256  0.982961       NaN  0.981044  0.982960
# 6   swinv2_small_patch4_window8_256  0.832370  0.502660  0.661339  0.810767
# 7   swinv2_tiny_patch4_window16_256  0.831647  0.492833  0.660615  0.815226
# 8             vit_small_patch16_224  0.984793       NaN  0.983081  0.984817
# 9                convnext_small_224  0.892986  0.556481  0.162967  0.943002
# 10           deit_small_patch16_224  0.980396       NaN  0.978188  0.980379
# 11            vit_small_patch16_224  0.810694  0.557585  0.619430  0.794992
# 12           deit_small_patch16_224  0.802746  0.600685  0.605909  0.790805
# 13                convnext_tiny_224  0.900206  0.603624  0.177469  0.947037
# 14             vit_tiny_patch16_224  0.978014       NaN  0.975529  0.978002
# 15            deit_tiny_patch16_224  0.973067       NaN  0.970033  0.973097
# 16             vit_tiny_patch16_224  0.804191  0.529103  0.605373  0.785432
# 17            deit_tiny_patch16_224  0.781792  0.567070  0.559209  0.756844
# 18  swinv2_small_patch4_window8_256  0.848891  0.488242  0.212901  0.917208
# 19  swinv2_tiny_patch4_window16_256  0.858948  0.449540  0.227551  0.923120
# 20            vit_small_patch16_224  0.797576  0.394460  0.204884  0.885685
# 21           deit_small_patch16_224  0.828778  0.563802  0.181165  0.905224
# 22             vit_tiny_patch16_224  0.832904  0.444893  0.189389  0.907692
# 23            deit_tiny_patch16_224  0.890150  0.581513  0.233310  0.941209
#
#     precision    recall  carbon_emissions model_size  model_id
# 0    0.951316  0.951081          0.026128      Small  convnext
# 1    0.790861  0.714286          0.017468      Small  convnext
# 2    0.959581  0.959509          0.016284      Small  convnext
# 3    0.760196  0.739683          0.011218      Small  convnext
# 4    0.985783  0.985709          0.008626      Small    swinv2
# 5    0.983102  0.982961          0.006457      Small    swinv2
# 6    0.833893  0.788889          0.005896      Small    swinv2
# 7    0.814580  0.815873          0.004486      Small    swinv2
# 8    0.984919  0.984793          0.002646      Small       vit
# 9    0.991910  0.898691          0.002371      Small  convnext
# 10   0.980515  0.980396          0.002161      Small      deit
# 11   0.783951  0.806349          0.001870      Small       vit
# 12   0.764444  0.819048          0.001632      Small      deit
# 13   0.992257  0.905759          0.001517      Small  convnext
# 14   0.978055  0.978014          0.001489      Small       vit
# 15   0.973293  0.973067          0.001297      Small      deit
# 16   0.783570  0.787302          0.001137      Small       vit
# 17   0.767974  0.746032          0.001033      Small      deit
# 18   0.996317  0.849738          0.000805      Small    swinv2
# 19   0.996662  0.859686          0.000589      Small    swinv2
# 20   0.998031  0.796073          0.000244      Small       vit
# 21   0.995292  0.830105          0.000216      Small      deit
# 22   0.995625  0.834031          0.000151      Small       vit
# 23   0.995330  0.892670          0.000134      Small      deit
